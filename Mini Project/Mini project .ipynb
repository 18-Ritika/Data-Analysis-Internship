# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_activities = pd.read_csv("cardioActivities.csv",parse_dates=True,index_col="Date")

# %%
df_activities
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running        NaN
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running        NaN
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running        NaN
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running        NaN
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running        NaN
# ...                                                   ...      ...        ...
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking        NaN
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking        NaN
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking        NaN
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running        NaN
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running        NaN
#
# ...

# %%
df_activities.head()
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running        NaN
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running        NaN
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running        NaN
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running        NaN
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# 2018-11-09 15:02:35          12.84  1:14:12         5:47
# 2018-11-04 16:05:00          13.01  1:15:16         5:47
# 2018-11-01 14:03:58          12.98  1:14:25         5:44
# 2018-10-27 17:01:36          13.02  1:12:50         5:36
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# ...

# %%
df_activities.sample(3)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2015-12-06 12:54:29  2c3636ee-cb13-4f41-80c7-2373427859ac  Running        NaN
# 2014-12-08 16:18:00  48eebce4-1d5f-4700-856d-754f24292b2e  Running        NaN
# 2015-07-24 18:49:43  0998a635-1166-4d12-b143-56a922e05fd2  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2015-12-06 12:54:29          13.77  1:18:04         5:40
# 2014-12-08 16:18:00           6.63    32:00         4:49
# 2015-07-24 18:49:43          12.69  1:05:15         5:09
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2015-12-06 12:54:29                 10.58           1009.0        146
# 2014-12-08 16:18:00                 12.44            431.0         33
# 2015-07-24 18:49:43                 11.67            858.0        108
#
#                      Average Heart Rate (bpm)  Friend's Tagged Notes  \
# Date
# ...

# %%
df_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 508 entries, 2018-11-11 14:05:12 to 2012-08-22 18:53:54
# Data columns (total 13 columns):
# Activity Id                 508 non-null object
# Type                        508 non-null object
# Route Name                  1 non-null object
# Distance (km)               508 non-null float64
# Duration                    508 non-null object
# Average Pace                508 non-null object
# Average Speed (km/h)        508 non-null float64
# Calories Burned             508 non-null float64
# Climb (m)                   508 non-null int64
# Average Heart Rate (bpm)    294 non-null float64
# Friend's Tagged             0 non-null float64
# Notes                       231 non-null object
# GPX File                    504 non-null object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 55.6+ KB

# %%
cols = ['Route Name',"Friend's Tagged","Notes"]
col_to_drop = df_activities.drop(cols,axis =1,inplace = True)

# %%
df_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 508 entries, 2018-11-11 14:05:12 to 2012-08-22 18:53:54
# Data columns (total 10 columns):
# Activity Id                 508 non-null object
# Type                        508 non-null object
# Distance (km)               508 non-null float64
# Duration                    508 non-null object
# Average Pace                508 non-null object
# Average Speed (km/h)        508 non-null float64
# Calories Burned             508 non-null float64
# Climb (m)                   508 non-null int64
# Average Heart Rate (bpm)    294 non-null float64
# GPX File                    504 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 43.7+ KB

# %%
df_activities["Type"].value_counts()
# Out:
# Running    459
# Cycling     29
# Walking     18
# Other        2
# Name: Type, dtype: int64

# %%
df_activities["Type"] = df_activities["Type"].str.replace("Other","Unicycling")

# %%
df_activities["Type"].value_counts()
# Out:
# Running       459
# Cycling        29
# Walking        18
# Unicycling      2
# Name: Type, dtype: int64

# %%
df_activities.head()
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# 2018-11-09 15:02:35          12.84  1:14:12         5:47
# 2018-11-04 16:05:00          13.01  1:15:16         5:47
# 2018-11-01 14:03:58          12.98  1:14:25         5:44
# 2018-10-27 17:01:36          13.02  1:12:50         5:36
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2018-11-11 14:05:12                 10.68            774.0        130
# ...

# %%
df_activities.isnull().sum()
# Out:
# Activity Id                   0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# GPX File                      4
# dtype: int64

# %%
avg_hr_cycle = df_activities[df_activities["Type"]== "Cycling"]
avg_hr_cycle = avg_hr_cycle["Average Heart Rate (bpm)"].mean()
avg_hr_cycle = int(avg_hr_cycle)
avg_hr_cycle
# Out:
# 124

# %%
df_cycle = df_activities[df_activities["Type"]=="Cycling"].copy()

# %%
df_cycle.head(20)
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4  Cycling
# 2018-09-16 14:55:03  30aaa821-1d3a-4f2f-9688-8543cebbd6e8  Cycling
# 2018-09-01 17:06:15  2bd1841f-b428-4683-a41b-2bfb4be7e908  Cycling
# 2018-08-28 18:44:33  c9a8e088-441d-4b3f-bfbc-287e87585ca7  Cycling
# 2018-08-25 17:18:32  12723b6e-571b-4b68-be17-2c797982d3f9  Cycling
# 2017-09-22 12:27:14  4817879b-dedb-4b3d-a2e8-92d41757ccea  Cycling
# 2017-08-17 18:36:00  3c980f93-7aa1-477c-9f90-72ca01552031  Cycling
# 2017-05-01 17:38:35  9a5c1022-08f3-4c9b-9cc5-492d4d7178f9  Cycling
# 2016-10-03 11:47:16  d7f518d9-57aa-4c3f-b5d1-a3f758155737  Cycling
# 2016-09-10 17:13:51  be77ab12-11b2-4604-828d-6ac7ee0b6c50  Cycling
# 2016-09-04 17:08:28  cc9e2d95-fc5d-4633-9801-a6a92df8eebe  Cycling
# 2016-08-27 17:08:38  e3fc3373-0a83-4dba-8042-7eca0b3cf676  Cycling
# 2016-08-20 15:43:49  d71c6646-114b-4fb9-a011-d195c560591b  Cycling
# ...

# %%
df_cycle["Average Heart Rate (bpm)"].fillna(avg_hr_cycle)
# Out:
# Date
# 2018-10-06 16:45:02     79.0
# 2018-09-16 14:55:03    118.0
# 2018-09-01 17:06:15    122.0
# 2018-08-28 18:44:33    111.0
# 2018-08-25 17:18:32    124.0
# 2017-09-22 12:27:14    124.0
# 2017-08-17 18:36:00    138.0
# 2017-05-01 17:38:35    135.0
# 2016-10-03 11:47:16    126.0
# 2016-09-10 17:13:51    136.0
# 2016-09-04 17:08:28    134.0
# 2016-08-27 17:08:38    134.0
# 2016-08-20 15:43:49    138.0
# 2016-08-17 17:17:09    122.0
# 2016-05-22 15:31:06    124.0
# 2015-10-18 15:43:06    124.0
# 2015-08-23 17:35:47    124.0
# 2015-08-15 18:46:21    124.0
# 2015-08-01 18:40:14    124.0
# 2015-06-21 17:53:46    124.0
# 2015-06-14 17:03:23    124.0
# 2015-06-06 18:30:39    124.0
# 2015-05-31 04:02:00    124.0
# 2015-05-23 19:07:40    124.0
# 2015-05-01 18:05:38    125.0
# 2014-08-29 18:56:02    124.0
# 2013-05-09 17:24:19    124.0
# 2013-05-05 14:26:37    124.0
# 2013-04-28 17:26:52    124.0
# Name: Average Heart Rate (bpm), dtype: float64

# %%
df_run = df_activities[df_activities["Type"]=="Running"].copy()

# %%
df_run.isnull().sum()
# Out:
# Activity Id                   0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    182
# GPX File                      4
# dtype: int64

# %%
runs_subset_2013_2018 = df_run[:'2013-01-01']
runs_subset_2013_2018
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2013-01-23 18:38:29  0ee9afe5-668e-4801-9fd3-6208ec87f2e6  Running
# 2013-01-19 09:58:50  98321fac-a333-47d7-b568-1c609096a08f  Running
# 2013-01-15 18:40:08  7c512661-6a01-4ef0-80dd-b8119d5f8a59  Running
# 2013-01-12 08:39:55  3a08d9a1-fc17-4002-80c1-419700be1e22  Running
# 2013-01-02 18:35:11  57ff5696-7610-4296-903a-88c63c207603  Running
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# ...

# %%
runs_subset_2013_2018.plot(subplots=True,figsize=(6,4), marker="+", markersize=10)
plt.show()

# %%
runs_subset_2015_2018 = df_run[:'2015-01-01']

#runs_subset_2015_2018["Distance (km)"].resample('A').mean()
runs_subset_2015_2018.resample("A").mean()
# Out:
#             Distance (km)  Average Speed (km/h)  Calories Burned   Climb (m)  \
# Date
# 2015-12-31      13.602805             10.998902       932.906138  160.170732
# 2016-12-31      11.411667             10.837778       796.152777  133.194444
# 2017-12-31      12.935176             10.959059       914.164706  169.376471
# 2018-12-31      13.339063             10.777969       952.359375  191.218750
#
#             Average Heart Rate (bpm)
# Date
# 2015-12-31                143.231884
# 2016-12-31                143.301587
# 2017-12-31                145.277108
# 2018-12-31                148.258065

# %%
#runs_subset_2015_2018["Distance (km)"].resample('W').mean().mean()
runs_subset_2015_2018.resample("W").mean().mean()
# Out:
# Distance (km)                12.518176
# Average Speed (km/h)         10.835473
# Calories Burned             877.861969
# Climb (m)                   158.325444
# Average Heart Rate (bpm)    144.925000
# dtype: float64

# %%
distance_sample=runs_subset_2015_2018.filter(items=["Distance (km)"])

# %%
weekly_counts_average = distance_sample.resample('W').count().mean()
weekly_counts_average
# Out:
# Distance (km)    1.5
# dtype: float64

# %%
runs_distance=runs_subset_2015_2018["Distance (km)"]
runs_hr=runs_subset_2015_2018["Average Heart Rate (bpm)"]

# %%
#fig = plt.figure(figsize=(12,8))
#ax1 = plt.subplot(211)
#ax2 = plt.subplot(212)

#ax1.plot(runs_subset_2015_2018.index,runs_distance)
#ax2.plot(runs_subset_2015_2018.index,runs_hr)

#ax1.get_shared_x_axes().join(ax1,ax2)
#ax1.set_xticklabels([])
#plt.axhline(y= runs_hr.mean,color="blue",linestyle ="-.")
#plt.show

fig, (ax1,ax2) = plt.subplots(2, sharex=True, figsize=(12,8))
runs_distance.plot(ax=ax1 , color="Blue")  #first plot
ax1.set(ylabel="Dsitance (km)", title="Avergae Data")
ax1.axhline(runs_distance.mean(),color="Brown",linewidth = 1, linestyle = '-.')

runs_hr.plot(ax=ax2, color="Pink")
ax2.set(xlabel="Date", ylabel="Average Heart Rate (bpm)")
ax2.axhline(runs_hr.mean(), color="Brown",linewidth = 1, linestyle = '-.')

plt.show()

# %%
df_run = df_run[:'2013-01-01']
df_run_dist_annual = df_run["Distance (km)"].resample('A').sum()
df_run_dist_annual
# Out:
# Date
# 2013-12-31     498.25
# 2014-12-31     755.76
# 2015-12-31    1115.43
# 2016-12-31     821.64
# 2017-12-31    1099.49
# 2018-12-31     853.70
# Freq: A-DEC, Name: Distance (km), dtype: float64

# %%
fig = plt.figure(figsize=(5,8))
ax = df_run_dist_annual.plot(marker="*",linewidth=0, color="Black")
ax.set(xlim= ["2012","2018"],ylim = [0,800],title = "Annual Running Distance (km) ")
plt.xlabel("Years")
plt.ylabel("Distance")
ax.axhspan(0,800,color="red",alpha = 0.2)
plt.show()

# %%
import statsmodels.api as sm
runs_subset_2013_2018 = df_run[:'2013-01-01']
df_run_dist_wkly =  runs_subset_2013_2018["Distance (km)"].resample("W").bfill()

# %%
fig = plt.figure(figsize=(12,5))
df_run_dist_wkly.plot(marker="*",label = "Trend", color="Brown")
plt.xlabel("Year")
plt.ylabel("Distance")
plt.title("Weekly Distance Run")
plt.show()

# %%
df_run_hr_all = df_run[:'2015-01-01']
df_run_hr_all = df_run_hr_all["Average Heart Rate (bpm)"]
df_run_hr_all
# Out:
# Date
# 2018-11-11 14:05:12    159.0
# 2018-11-09 15:02:35    159.0
# 2018-11-04 16:05:00    155.0
# 2018-11-01 14:03:58    158.0
# 2018-10-27 17:01:36    154.0
#                        ...
# 2015-01-28 18:43:29      NaN
# 2015-01-26 18:30:18      NaN
# 2015-01-14 17:50:00      NaN
# 2015-01-12 18:20:00      NaN
# 2015-01-03 17:20:00      NaN
# Name: Average Heart Rate (bpm), Length: 303, dtype: float64

# %%
zone_names = ["low", "min", "moderate","medium", "max","Extreme"]
fig,ax = plt.subplots(figsize=(8,5))
ax.hist(df_run_hr_all,color="brown")
ax.set_xticklabels(labels=zone_names,rotation=-30,ha='left')
plt.show()

# %%
f_walk = df_activities[df_activities["Type"]=="Walking"].copy()
df_walk["Average Heart Rate (bpm)"].fillna(110,inplace=True)

# %%
df_walk.isnull().sum()
# Out:
# Activity Id                 0
# Type                        0
# Distance (km)               0
# Duration                    0
# Average Pace                0
# Average Speed (km/h)        0
# Calories Burned             0
# Climb (m)                   0
# Average Heart Rate (bpm)    0
# GPX File                    0
# dtype: int64

# %%
avg_hr_cycle = df_activities.groupby("Type").mean()
df_cycle = df_activities[df_activities['Type']=='Cycling'].copy()
df_cycle['Average Heart Rate (bpm)'].fillna(124,inplace = True)
print(df_cycle.isnull().sum())
# Out:
# Activity Id                 0
# Type                        0
# Distance (km)               0
# Duration                    0
# Average Pace                0
# Average Speed (km/h)        0
# Calories Burned             0
# Climb (m)                   0
# Average Heart Rate (bpm)    0
# GPX File                    0
# dtype: int64

# %%
df_run_walk_cycle = df_activities.append([df_walk, df_cycle]).sort_index(ascending=False)

# %%
dist_climb_cols, speed_col = ["Distance (km)","Climb (m)"],["Average Heart Rate (bpm)"]

# %%
df_totals = df_run_walk_cycle.groupby("Type")[dist_climb_cols].sum()
display(df_totals)

df_summary = df_run_walk_cycle.groupby("Type")[dist_climb_cols + speed_col].describe()

for i in dist_climb_cols:
  df_summary[i, "total"] = df_totals[i]
print("Total Statistics")
df_summary.stack()
# Out:
#             Distance (km)  Climb (m)
# Type
# Cycling           1361.16      13952
# Running           5224.50      57278
# Unicycling          34.45        421
# Walking             66.90        698
# Total Statistics
#                   Average Heart Rate (bpm)     Climb (m)  Distance (km)
# Type
# Cycling    25%                  124.000000    139.000000      15.530000
#            50%                  124.000000    199.000000      20.300000
#            75%                  134.000000    318.000000      29.400000
#            count                 44.000000     58.000000      58.000000
#            max                  138.000000    553.000000      49.180000
#            mean                 124.272727    240.551724      23.468276
#            min                   79.000000     58.000000      11.410000
#            std                   12.004580    127.824053       9.367769
#            total                       NaN  13952.000000    1361.160000
# ...

# %%
average_shoes_lifetime = 5224/7 
average_shoes_lifetime
# Out:
# 746.2857142857143

# %%
shoes_for_forrest_run = 24700//average_shoes_lifetime
shoes_for_forrest_run
# Out:
# 33.0
